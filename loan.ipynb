# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_excel(r"C:\Users\Darshil Shetty\Downloads\loan_sanction.xlsx")

# %%
print(data)
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male                  2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 365  LP002971   Male     Yes         3+  Not Graduate           Yes
# 366  LP002975   Male     Yes          0      Graduate            No
# 367  LP002980   Male      No          0      Graduate            No
# 368  LP002986   Male     Yes          0      Graduate            No
# 369  LP002989   Male      No          0      Graduate           Yes
#
#     Applicant_Income  Coapplicant_Income LoanAmount  Loan_Amount_Term  \
# 0               5720                   0        110               360
# ...

# %%
data.columns.value_counts()
# Out:
# Loan_ID               1
# Gender                1
# Married               1
# Dependents            1
# Education             1
# Self_Employed         1
# Applicant_Income      1
# Coapplicant_Income    1
# LoanAmount            1
# Loan_Amount_Term      1
# Credit_History        1
# Property_Area         1
# Name: count, dtype: int64

# %%
#q1
print(data[data.duplicated()])
print(data.loc[329,:])
print(data.loc[4,:])
print(data.loc[58:60,:])
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 5    LP001051   Male      No          0  Not Graduate            No
# 59   LP001321   Male     Yes          2      Graduate            No
# 330  LP002805   Male     Yes          2      Graduate            No
#
#     Applicant_Income  Coapplicant_Income LoanAmount  Loan_Amount_Term  \
# 5               3276                   0         78               360
# 59              3613                3539        134               180
# 330             5041                 700        150               360
#
#     Credit_History Property_Area
# 5                1         Urban
# 59               1     Semiurban
# 330              1         Urban
# Loan_ID               LP002805
# Gender                    Male
# Married                    Yes
# Dependents                   2
# Education             Graduate
# Self_Employed               No
# Applicant_Income          5041
# Coapplicant_Income         700
# ...

# %%
#q2
print(data)
data.drop_duplicates()
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male                  2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 365  LP002971   Male     Yes         3+  Not Graduate           Yes
# 366  LP002975   Male     Yes          0      Graduate            No
# 367  LP002980   Male      No          0      Graduate            No
# 368  LP002986   Male     Yes          0      Graduate            No
# 369  LP002989   Male      No          0      Graduate           Yes
#
#     Applicant_Income  Coapplicant_Income LoanAmount  Loan_Amount_Term  \
# 0               5720                   0        110               360
# ...

# %%
#q3
for i in data:
 f=data.loc[:,i].isna()   
 print(f.value_counts()) 
 d=data[data.loc[:,i].isna()]
  
 print(d)
# Out:
# Loan_ID
# False    370
# Name: count, dtype: int64
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, Applicant_Income, Coapplicant_Income, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area]
# Index: []
# Gender
# False    368
# True       2
# Name: count, dtype: int64
#      Loan_ID Gender Married Dependents Education Self_Employed  \
# 13  LP001083    NaN      No         3+  Graduate            No
# 89  LP001466    NaN      No          0  Graduate            No
#
#    Applicant_Income  Coapplicant_Income LoanAmount  Loan_Amount_Term  \
# 13             4166                   0         40               180
# 89             3066                   0         95               360
#
#    Credit_History Property_Area
# 13              1         Urban
# 89              1     Semiurban
# Married
# False    370
# Name: count, dtype: int64
# Empty DataFrame
# ...

# %%
#q4
p=data.loc[:,:].isna()
p1=data.dropna()
print(p)
print(p1)
p1.reset_index().drop('index',axis=1)
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 365    False   False    False       False      False          False
# 366    False   False    False       False      False          False
# 367    False   False    False       False      False          False
# 368    False   False    False       False      False          False
# 369    False   False    False       False      False          False
#
#      Applicant_Income  Coapplicant_Income  LoanAmount  Loan_Amount_Term  \
# 0               False               False       False             False
# ...

# %%
#q5

p=data['Gender'].mode()[0]
print(p)
print(data.loc[13,:])
data['Gender'].fillna(p, inplace=True)
print(data)
# Out:
# 0    Male
# Name: Gender, dtype: object
# Loan_ID               LP001083
# Gender                    Male
# Married                     No
# Dependents                  3+
# Education             Graduate
# Self_Employed               No
# Applicant_Income          4166
# Coapplicant_Income           0
# LoanAmount                  40
# Loan_Amount_Term           180
# Credit_History               1
# Property_Area            Urban
# Name: 13, dtype: object
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male                  2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# ...

# %%
#q6

print(data['Self_Employed'].mode())
data['Self_Employed'].fillna(data['Self_Employed'].mode())[0]
print(data)
# Out:
# 0    No
# Name: Self_Employed, dtype: object
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male                  2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 365  LP002971   Male     Yes         3+  Not Graduate           Yes
# 366  LP002975   Male     Yes          0      Graduate            No
# 367  LP002980   Male      No          0      Graduate            No
# 368  LP002986   Male     Yes          0      Graduate            No
# 369  LP002989   Male      No          0      Graduate           Yes
#
#     Applicant_Income  Coapplicant_Income LoanAmount  Loan_Amount_Term  \
# ...

# %%
#q7=
print(data['LoanAmount'].dtype)
print(data['LoanAmount'].dtype)
data[data['LoanAmount'].isnull()]
data['LoanAmount'].replace('',120)


data.loc[122,'LoanAmount']='NaN'
data.loc[361,'LoanAmount']='Nan'
data['LoanAmount']=pd.to_numeric(data['LoanAmount'],errors='coerce')
print(data['LoanAmount'].dtype)
print(data[data['LoanAmount'].isna()])
data.fillna(data['LoanAmount'].mode())
data[data['LoanAmount'].isna()]
p=data['LoanAmount'].mean()
print(p)
data['LoanAmount'].fillna(p,inplace=True)
data[data['LoanAmount'].isna()]
# Out:
# float64
# float64
# float64
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 122  LP001627   Male      No          0      Graduate            No
# 361  LP002954   Male     Yes          2  Not Graduate            No
#
#     Applicant_Income  Coapplicant_Income  LoanAmount  Loan_Amount_Term  \
# 122             3125                   0         NaN               360
# 361             3132                   0         NaN               360
#
#     Credit_History Property_Area
# 122              1         Urban
# 361              1         Rural
# 162.6304347826087
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, Applicant_Income, Coapplicant_Income, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area]
# Index: []

# %%
data[data['LoanAmount'].isna()]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, Applicant_Income, Coapplicant_Income, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area]
# Index: []

# %%
#q8
data.head(5)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male                  2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#   Applicant_Income  Coapplicant_Income  LoanAmount  Loan_Amount_Term  \
# 0             5720                   0       110.0               360
# 1             3076                1500       126.0               360
# 2             5000                1800       208.0               360
# 3             2340                2546       100.0               360
# 4             3276                   0        78.0               360
#
#   Credit_History Property_Area
# 0              1         Urban
# 1              1         Urban
# 2              1         Urban
# ...

# %%
#q9
data.to_excel('data.xlsx')

# %%
#q10
print(data.shape)
# Out:
# (370, 12)

# %%
#q11
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'Applicant_Income', 'Coapplicant_Income', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
#q12
data.describe()
# Out:
#        Coapplicant_Income   LoanAmount  Loan_Amount_Term
# count          370.000000   370.000000        370.000000
# mean          1568.308108   162.630435        342.475676
# std           2328.857392   516.446378         64.961867
# min              0.000000   -88.000000          6.000000
# 25%              0.000000   102.000000        360.000000
# 50%           1012.500000   125.000000        360.000000
# 75%           2437.250000   158.000000        360.000000
# max          24000.000000  9999.000000        480.000000

# %%
#q19=
data.corr(method='pearson',numeric_only=True)
# Out:
#                     Coapplicant_Income  LoanAmount  Loan_Amount_Term
# Coapplicant_Income            1.000000    0.098799         -0.015040
# LoanAmount                    0.098799    1.000000          0.024692
# Loan_Amount_Term             -0.015040    0.024692          1.000000

# %%
#q17
print(data['Gender'].unique())
data[data['Gender'].isna()]
# Out:
# ['Male' 'Female' '?']
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, Applicant_Income, Coapplicant_Income, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area]
# Index: []

# %%
#q15
print(data['Self_Employed'].mode()[0])

print(data['Self_Employed'].value_counts())
print(data[data['Self_Employed']=='Yes'])
# Out:
# No
# Self_Employed
# No            332
# Yes            34
#                 2
# Don't know      1
# 78              1
# Name: count, dtype: int64
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 6    LP001054    Male     Yes          0  Not Graduate           Yes
# 38   LP001210       ?     Yes          0      Graduate           Yes
# 39   LP001211    Male      No          0      Graduate           Yes
# 50   LP001270    Male     Yes         3+  Not Graduate           Yes
# 63   LP001335    Male     Yes          0      Graduate           Yes
# 75   LP001380    Male     Yes          0      Graduate           Yes
# 79   LP001413    Male      No          0      Graduate           Yes
# 92   LP001475    Male     Yes          0      Graduate           Yes
# 112  LP001584  Female       #          0      Graduate           Yes
# 134  LP001728    Male     Yes          1      Graduate           Yes
# ...

# %%
#q16
print(data['Property_Area'].value_counts())
print(data[data['Property_Area']=='Urban'])
# Out:
# Property_Area
# Urban        142
# Semiurban    117
# Rural        111
# Name: count, dtype: int64
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001015    Male     Yes          0      Graduate            No
# 1    LP001022    Male     Yes          1      Graduate            No
# 2    LP001031    Male     Yes          2      Graduate            No
# 3    LP001035    Male                  2      Graduate            No
# 4    LP001051    Male      No          0  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 359  LP002935    Male     Yes          1      Graduate            No
# 360  LP002952    Male      No          0      Graduate            No
# 363  LP002965  Female     Yes          0      Graduate            No
# 365  LP002971    Male     Yes         3+  Not Graduate           Yes
# 366  LP002975    Male     Yes          0      Graduate            No
#
# ...

# %%
#q18
q1=np.quantile(data['LoanAmount'],0.25)
q3=np.quantile(data['LoanAmount'],0.75)
IQR=q3-q1
outlier=(data['LoanAmount']<q1-IQR*1.5) & (data['LoanAmount']>q3+IQR*1.5)
print(outlier)
data.loc[outlier,'LoanAmount']=data['LoanAmount'].mean()
data['Credit_History']=pd.to_numeric(data['Credit_History'],errors='coerce')
print(data['Credit_History'].dtype)
q11=np.quantile(data['Credit_History'],0.25)
q33=np.quantile(data['Credit_History'],0.75)
IQR1=q3-q1
outlier1=(data['Credit_History']<q11-IQR1*1.5) & (data['Credit_History']>q33+IQR1*1.5)
print(outlier1)
data.loc[outlier,'Credit_History']=data['Credit_History'].mean()
print(data)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 365    False
# 366    False
# 367    False
# 368    False
# 369    False
# Name: LoanAmount, Length: 370, dtype: bool
# float64
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 365    False
# 366    False
# 367    False
# 368    False
# 369    False
# Name: Credit_History, Length: 370, dtype: bool

# %%
#q13
data._get_numeric_data()
# Out:
#      Coapplicant_Income  LoanAmount  Loan_Amount_Term  Credit_History
# 0                     0       110.0               360             1.0
# 1                  1500       126.0               360             1.0
# 2                  1800       208.0               360             1.0
# 3                  2546       100.0               360             1.0
# 4                     0        78.0               360             1.0
# ..                  ...         ...               ...             ...
# 365                1777       113.0               360             1.0
# 366                 709       115.0               360             1.0
# 367                1993       126.0               360             1.0
# 368                2393       158.0               360             1.0
# 369                   0        98.0               180             1.0
#
# [370 rows x 4 columns]

# %%
#q14
data[data.columns[data.dtypes!=object]]
# Out:
#      Coapplicant_Income  LoanAmount  Loan_Amount_Term  Credit_History
# 0                     0       110.0               360             1.0
# 1                  1500       126.0               360             1.0
# 2                  1800       208.0               360             1.0
# 3                  2546       100.0               360             1.0
# 4                     0        78.0               360             1.0
# ..                  ...         ...               ...             ...
# 365                1777       113.0               360             1.0
# 366                 709       115.0               360             1.0
# 367                1993       126.0               360             1.0
# 368                2393       158.0               360             1.0
# 369                   0        98.0               180             1.0
#
# [370 rows x 4 columns]
